# %%
import pandas as pd

# Define the file paths
file1 = r"C:\Users\pingk\Downloads\fadhli nitip\asik_rt4_now with indo new.csv"
file2 = r"C:\Users\pingk\Downloads\fadhli nitip\asik6a.csv"

# Read the CSV files into dataframes
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# Merge the dataframes, matching columns by name
merged_df = pd.concat([df1, df2], ignore_index=True, sort=False)

# Save the merged dataframe to a new CSV file
output_file = r"C:\Users\pingk\Downloads\fadhli nitip\fullfledgert46.csv"
merged_df.to_csv(output_file, index=False)

print(f"Merged CSV saved to {output_file}")
# Out:
# Merged CSV saved to C:\Users\pingk\Downloads\fadhli nitip\fullfledgert46.csv
