# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
country_mapping = pd.read_excel(r"C:\Users\pingk\Downloads\fadhli nitip\country_mapping.xlsx")
country_2digit = pd.read_excel(r"C:\Users\pingk\Downloads\fadhli nitip\country_2digit.xlsx")
provincial_code = pd.read_excel(r"C:\Users\pingk\Downloads\fadhli nitip\provincial code.xlsx")
three_group_precipitation = pd.read_excel(r"C:\Users\pingk\Downloads\fadhli nitip\three_group_precipitation.xlsx")
four_group_precipitation = pd.read_excel(r"C:\Users\pingk\Downloads\fadhli nitip\four_group_precipitation.xlsx")
island_mapping = pd.read_excel(r"C:\Users\pingk\Downloads\fadhli nitip\island code.xlsx")
thai_mapping = pd.read_excel(r"C:\Users\pingk\Downloads\fadhli nitip\thai_vs_nothai.xlsx")

data_rt4 = pd.read_csv(r"C:\Users\pingk\Downloads\fadhli nitip\fadhli nitip\csv\data_rt4_raw_nodrop_removedbadfiles.csv")
data_rt1 = pd.read_csv(r"C:\Users\pingk\Downloads\fadhli nitip\fadhli nitip\csv\data_rt1_raw_nodrop.csv")
data_rt3a = pd.read_csv(r"C:\Users\pingk\Downloads\fadhli nitip\fadhli nitip\csv\data_rt3_raw_nodrop_a.csv")
data_rt3b = pd.read_csv(r"C:\Users\pingk\Downloads\fadhli nitip\fadhli nitip\csv\data_rt3_raw_nodrop_b.csv")
data_rt6 = pd.read_csv(r"C:\Users\pingk\Downloads\fadhli nitip\fadhli nitip\csv\data_rt6_raw_nodrop.csv")
data_rt11 = pd.read_csv(r"C:\Users\pingk\Downloads\fadhli nitip\fadhli nitip\csv\data_rt11_raw_nodrop.csv")
# Out:
# Data files loaded successfully.

# %%
# Inspect the first few rows of each dataset
print("Raw Data:")
raw_data.head()
# Out:
# Raw Data:
#   prov_char  country_code country_char               wavenumber  4000.122  \
# 0       BBX             1           ID  ID-BBX-068-2307-031_001  0.000788
# 1       BBX             1           ID  ID-BBX-068-2307-031_002  0.001095
# 2       BBX             1           ID  ID-BBX-068-2307-031_003  0.000099
# 3       BBX             1           ID  ID-BBX-068-2307-031_004  0.001685
# 4       BBX             1           ID  ID-BBX-068-2307-031_005  0.002118
#
#     3999.64  3999.158  3998.676  3998.194  3997.712  ...    653.75   653.268  \
# 0  0.000813  0.000840  0.000858  0.000862  0.000843  ...  0.011951  0.013370
# 1  0.001078  0.001086  0.001114  0.001151  0.001180  ...  0.012086  0.011914
# 2  0.000153  0.000288  0.000470  0.000658  0.000814  ...  0.010487  0.011307
# 3  0.001802  0.001903  0.001975  0.002017  0.002031  ...  0.008177  0.008240
# 4  0.002196  0.002266  0.002324  0.002369  0.002404  ...  0.009831  0.010143
#
# ...

# %%
print("\nFiltered Data:")
filtered_data.head()
# Out:
# Filtered Data:
#   prov_char  country_code country_char               wavenumber  3099.528  \
# 0       BBX             1           ID  ID-BBX-068-2307-031_001  0.002471
# 1       BBX             1           ID  ID-BBX-068-2307-031_002  0.002932
# 2       BBX             1           ID  ID-BBX-068-2307-031_003  0.001651
# 3       BBX             1           ID  ID-BBX-068-2307-031_004  0.003385
# 4       BBX             1           ID  ID-BBX-068-2307-031_005  0.002765
#
#    3099.046  3098.564  3098.082    3097.6  3097.118  ...   654.232    653.75  \
# 0  0.002400  0.002327  0.002251  0.002176  0.002106  ...  0.010798  0.011951
# 1  0.002932  0.002909  0.002861  0.002796  0.002721  ...  0.012223  0.012086
# 2  0.001675  0.001680  0.001666  0.001634  0.001589  ...  0.010014  0.010487
# 3  0.003437  0.003485  0.003524  0.003555  0.003571  ...  0.008214  0.008177
# 4  0.002775  0.002776  0.002755  0.002706  0.002632  ...  0.009767  0.009831
#
# ...

# %%
print("\nProvincial Codes:")
provincial_codes.head()
# Out:
# Provincial Codes:
#   prov__char
# 0        SNI
# 1        KBI
# 2        CPN
# 3        SKM
# 4        PKN

# %%
# Display basic information about each dataset
print("\nRaw Data Info:")
raw_data.info()
# Out:
# Raw Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Columns: 6955 entries, prov_char to 16158804.55800001
# dtypes: float64(6951), int64(1), object(3)
# memory usage: 23.7+ MB

# %%
print("\nFiltered Data Info:")
filtered_data.info()
# Out:
# Filtered Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Columns: 3364 entries, prov_char to 649.893
# dtypes: float64(3360), int64(1), object(3)
# memory usage: 11.5+ MB

# %%
print("\nProvincial Codes Info:")
provincial_codes.info()
# Out:
# Provincial Codes Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   prov__char  28 non-null     object
# dtypes: object(1)
# memory usage: 356.0+ bytes

# %%
# Create ftir_data0 with specified columns from raw_data
ftir_data0 = raw_data.iloc[:, 4:-1]

# Verify the creation of ftir_data0
print("FTIR Data 0:")
print(ftir_data0.head())
print(ftir_data0.info())
# Out:
# FTIR Data 0:
#    4000.122   3999.64  3999.158  3998.676  3998.194  3997.712   3997.23  \
# 0  0.000788  0.000813  0.000840  0.000858  0.000862  0.000843  0.000797
# 1  0.001095  0.001078  0.001086  0.001114  0.001151  0.001180  0.001182
# 2  0.000099  0.000153  0.000288  0.000470  0.000658  0.000814  0.000909
# 3  0.001685  0.001802  0.001903  0.001975  0.002017  0.002031  0.002019
# 4  0.002118  0.002196  0.002266  0.002324  0.002369  0.002404  0.002435
#
#    3996.747  3996.265  3995.783  ...   654.232    653.75   653.268   652.786  \
# 0  0.000719  0.000609  0.000476  ...  0.010798  0.011951  0.013370  0.014849
# 1  0.001144  0.001064  0.000951  ...  0.012223  0.012086  0.011914  0.011799
# 2  0.000928  0.000871  0.000755  ...  0.010014  0.010487  0.011307  0.012372
# 3  0.001983  0.001925  0.001851  ...  0.008214  0.008177  0.008240  0.008484
# 4  0.002460  0.002472  0.002461  ...  0.009767  0.009831  0.010143  0.010621
#
# ...

# %%
# Check for duplicates in raw_data, filtered_data, and ftir_data0
filtered_data_duplicates = filtered_data.duplicated().sum()
ftir_data0_duplicates = ftir_data0.duplicated().sum()

print(f"Duplicates in Filtered Data: {filtered_data_duplicates}")
print(f"Duplicates in FTIR Data 0: {ftir_data0_duplicates}")
# Out:
# Duplicates in Filtered Data: 0
# Duplicates in FTIR Data 0: 0

# %%
# Check for missing values in raw_data, filtered_data, and ftir_data0
filtered_data_missing = filtered_data.isna().sum()
ftir_data0_missing = ftir_data0.isna().sum()

print("\nMissing Values in Filtered Data:")
print(filtered_data_missing[filtered_data_missing > 0])

print("\nMissing Values in FTIR Data 0:")
print(ftir_data0_missing[ftir_data0_missing > 0])
# Out:
# Missing Values in Filtered Data:
# Series([], dtype: int64)
#
# Missing Values in FTIR Data 0:
# Series([], dtype: int64)

# %%
# Count the number of samples per province and per country in filtered_data
sample_count_per_province_filtered = filtered_data['prov_char'].value_counts()
sample_count_per_country_filtered = filtered_data['country_char'].value_counts()

# Count the number of samples per province and per country in raw_data (since ftir_data0 is derived from it)
sample_count_per_province_raw = raw_data['prov_char'].value_counts()
sample_count_per_country_raw = raw_data['country_char'].value_counts()

print("Sample Count per Province in Filtered Data:")
print(sample_count_per_province_filtered)

print("\nSample Count per Country in Filtered Data:")
print(sample_count_per_country_filtered)

print("\nSample Count per Province in Raw Data:")
print(sample_count_per_province_raw)

print("\nSample Count per Country in Raw Data:")
print(sample_count_per_country_raw)
# Out:
# Sample Count per Province in Filtered Data:
# prov_char
# SNI    75
# CPN    42
# TRG    39
# KBI    37
# NRT    24
# SNK    24
# NWT    24
# BBX    18
# KBX    18
# PKN    18
# SUX    18
# RNG    16
# STN    15
# CCO    13
# CBI    12
# RIX    11
# SGR    11
# PTN     7
# KRI     6
# KTX     5
# SSX     3
# PNA     3
# PLG     3
# SKM     3
# JHR     2
# Name: count, dtype: int64
#
# Sample Count per Country in Filtered Data:
# country_char
# TH    361
# ID     73
# MY     13
# Name: count, dtype: int64
#
# Sample Count per Province in Raw Data:
# prov_char
# SNI    75
# CPN    42
# TRG    39
# KBI    37
# NRT    24
# SNK    24
# NWT    24
# BBX    18
# KBX    18
# PKN    18
# SUX    18
# RNG    16
# STN    15
# CCO    13
# CBI    12
# RIX    11
# SGR    11
# PTN     7
# KRI     6
# KTX     5
# SSX     3
# PNA     3
# PLG     3
# SKM     3
# JHR     2
# Name: count, dtype: int64
#
# Sample Count per Country in Raw Data:
# country_char
# TH    361
# ID     73
# MY     13
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the matplotlib figure
plt.figure(figsize=(12, 6))

# Plot the distribution of samples per province in filtered_data
plt.subplot(1, 2, 1)
sns.countplot(y='prov_char', data=filtered_data, order=filtered_data['prov_char'].value_counts().index)
plt.title('Distribution of Samples per Province in Filtered Data')
plt.xlabel('Count')
plt.ylabel('Province')

# Plot the distribution of samples per country in filtered_data
plt.subplot(1, 2, 2)
sns.countplot(y='country_char', data=filtered_data, order=filtered_data['country_char'].value_counts().index)
plt.title('Distribution of Samples per Country in Filtered Data')
plt.xlabel('Count')
plt.ylabel('Country')

# Display the plots
plt.tight_layout()
plt.show()

# %%
# LOOCV Setup
def loocv_setup(data, leave_out_provinces):
    loocv_data = data[data['prov_char'].isin(leave_out_provinces)]
    remaining_data = data[~data['prov_char'].isin(leave_out_provinces)]
    return loocv_data, remaining_data

# Define the provinces to leave out for LOOCV
leave_out_provinces = ['SKM', 'PLG', 'SSX', 'JHR']

# Perform LOOCV Setup
loocv_data, remaining_data = loocv_setup(filtered_data, leave_out_provinces)

# Verify the shapes of the resulting data frames
print(f"LOOCV Data Shape: {loocv_data.shape}")
print(f"Remaining Data Shape: {remaining_data.shape}")

# Display the first few rows of LOOCV Data and Remaining Data
print("LOOCV Data:")
print(loocv_data.head())

print("\nRemaining Data:")
print(remaining_data.head())
# Out:
# LOOCV Data Shape: (11, 3364)
# Remaining Data Shape: (436, 3364)
# LOOCV Data:
#     prov_char  country_code country_char               wavenumber  3099.528  \
# 52        SSX             1           ID  ID-SSX-068-2307-028_001  0.002032
# 53        SSX             1           ID  ID-SSX-068-2307-028_002  0.001743
# 54        SSX             1           ID  ID-SSX-068-2307-028_003  0.002459
# 249       PLG             0           TH  TH-PLG-002-2209-022_001  0.002356
# 250       PLG             0           TH  TH-PLG-002-2209-022_002  0.003575
#
#      3099.046  3098.564  3098.082    3097.6  3097.118  ...   654.232  \
# 52   0.002053  0.002090  0.002141  0.002199  0.002253  ...  0.010885
# 53   0.001712  0.001692  0.001686  0.001695  0.001718  ...  0.013582
# 54   0.002432  0.002368  0.002282  0.002185  0.002091  ...  0.011873
# 249  0.002346  0.002360  0.002397  0.002453  0.002520  ...  0.007780
# 250  0.003574  0.003572  0.003578  0.003599  0.003633  ...  0.010931
#
# ...

# %%
import numpy as np

# Select only numeric columns from remaining_data
numeric_columns = remaining_data.select_dtypes(include=[np.number]).columns
remaining_numeric_data = remaining_data[numeric_columns]

# Display basic information about the numeric data
print("Numeric Data Info:")
print(remaining_numeric_data.info())

# Display first few rows of the numeric data
print("\nFirst Few Rows of Numeric Data:")
print(remaining_numeric_data.head())
# Out:
# Numeric Data Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 436 entries, 0 to 446
# Columns: 3361 entries, country_code to 649.893
# dtypes: float64(3360), int64(1)
# memory usage: 11.2 MB
# None
#
# First Few Rows of Numeric Data:
#    country_code  3099.528  3099.046  3098.564  3098.082    3097.6  3097.118  \
# 0             1  0.002471  0.002400  0.002327  0.002251  0.002176  0.002106
# 1             1  0.002932  0.002932  0.002909  0.002861  0.002796  0.002721
# 2             1  0.001651  0.001675  0.001680  0.001666  0.001634  0.001589
# 3             1  0.003385  0.003437  0.003485  0.003524  0.003555  0.003571
# 4             1  0.002765  0.002775  0.002776  0.002755  0.002706  0.002632
#
#    3096.636  3096.154  3095.671  ...   654.232    653.75   653.268   652.786  \
# 0  0.002054  0.002030  0.002042  ...  0.010798  0.011951  0.013370  0.014849
# 1  0.002646  0.002579  0.002526  ...  0.012223  0.012086  0.011914  0.011799
# ...

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Preprocessing Functions

class UV_SNV:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        scaler = StandardScaler()
        return scaler.fit_transform(X)

class UV_MSC:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        mean_spectrum = np.mean(X, axis=0)
        return (X - mean_spectrum) / np.std(X, axis=0)

class UV_1der:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return np.gradient(X, axis=1)

class UV_2der:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return np.gradient(np.gradient(X, axis=1), axis=1)

class Par_SNV:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        scaler = StandardScaler()
        return scaler.fit_transform(X) / np.sqrt(np.var(X, axis=0))

class Par_MSC:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        mean_spectrum = np.mean(X, axis=0)
        return (X - mean_spectrum) / np.sqrt(np.var(X, axis=0))

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Preprocessing Methods
preprocessing_methods = {
    'UV-SNV': UV_SNV(),
    'UV-MSC': UV_MSC(),
    'UV-1-der': UV_1der(),
    'UV-2-der': UV_2der(),
    'Par-SNV': Par_SNV(),
    'Par-MSC': Par_MSC()
}

# Function to plot clusters
def plot_clusters(components, labels, title):
    plt.figure(figsize=(10, 7))
    sns.scatterplot(x=components[:, 0], y=components[:, 1], hue=labels, palette='viridis')
    plt.title(title)
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.legend(title='Country Code')
    plt.show()

# Select only numeric columns
numeric_columns = remaining_numeric_data.columns

# Plot without any preprocessing
print("Applying PCA without any preprocessing")
pipeline_no_preprocessing = Pipeline([
    ('pca', PCA(n_components=2))
])
no_preprocessing_data = pipeline_no_preprocessing.fit_transform(remaining_numeric_data)
plot_clusters(no_preprocessing_data, remaining_data['country_code'], 'PCA without Preprocessing')

# Apply and evaluate each preprocessing method individually
for method_name, method in preprocessing_methods.items():
    print(f"Applying preprocessing method: {method_name}")
    pipeline = Pipeline([
        ('preprocessing', method),
        ('pca', PCA(n_components=2))
    ])
    
    try:
        preprocessed_data = pipeline.fit_transform(remaining_numeric_data)
        print(f"Shape after {method_name} preprocessing: {preprocessed_data.shape}")
        plot_clusters(preprocessed_data, remaining_data['country_code'], f'PCA with {method_name} Preprocessing')
    except Exception as e:
        print(f"Error during {method_name} preprocessing: {e}")
# Out:
# Applying PCA without any preprocessing
# Applying preprocessing method: UV-SNV
# Shape after UV-SNV preprocessing: (436, 2)
# Applying preprocessing method: UV-MSC
# Shape after UV-MSC preprocessing: (436, 2)
# Applying preprocessing method: UV-1-der
# Shape after UV-1-der preprocessing: (436, 2)
# Applying preprocessing method: UV-2-der
# Shape after UV-2-der preprocessing: (436, 2)
# Applying preprocessing method: Par-SNV
# Error during Par-SNV preprocessing: Length of values (436) does not match length of index (3361)
# Applying preprocessing method: Par-MSC
# Shape after Par-MSC preprocessing: (436, 2)

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.patches import Ellipse

# Preprocessing Methods
preprocessing_methods = {
    'UV-SNV': UV_SNV(),
    'UV-MSC': UV_MSC(),
    'UV-1-der': UV_1der(),
    'UV-2-der': UV_2der(),
    'Par-SNV': Par_SNV(),
    'Par-MSC': Par_MSC()
}

# Function to plot clusters with filled confidence ellipses
def plot_clusters_with_ellipses(components, labels, title):
    plt.figure(figsize=(10, 7))
    scatter = sns.scatterplot(x=components[:, 0], y=components[:, 1], hue=labels, palette='viridis')
    
    # Add filled confidence ellipses
    unique_labels = np.unique(labels)
    palette = sns.color_palette('viridis', len(unique_labels))
    
    for label, color in zip(unique_labels, palette):
        subset = components[labels == label]
        if subset.shape[0] > 1:
            cov = np.cov(subset, rowvar=False)
            mean = np.mean(subset, axis=0)
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals = eigvals[order]
            eigvecs = eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * np.sqrt(eigvals)
            ellipse = Ellipse(xy=mean, width=width, height=height, angle=angle, 
                              edgecolor=color, facecolor=color, alpha=0.3, lw=1)
            plt.gca().add_patch(ellipse)
    
    plt.title(title)
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.legend(title='Country Code')
    plt.show()

# Select only numeric columns
numeric_columns = remaining_numeric_data.columns

# Plot without any preprocessing
print("Applying PCA without any preprocessing")
pipeline_no_preprocessing = Pipeline([
    ('pca', PCA(n_components=2))
])
no_preprocessing_data = pipeline_no_preprocessing.fit_transform(remaining_numeric_data)
plot_clusters_with_ellipses(no_preprocessing_data, remaining_data['country_code'], 'PCA without Preprocessing')

# Apply and evaluate each preprocessing method individually
for method_name, method in preprocessing_methods.items():
    print(f"Applying preprocessing method: {method_name}")
    pipeline = Pipeline([
        ('preprocessing', method),
        ('pca', PCA(n_components=2))
    ])
    
    try:
        preprocessed_data = pipeline.fit_transform(remaining_numeric_data)
        print(f"Shape after {method_name} preprocessing: {preprocessed_data.shape}")
        plot_clusters_with_ellipses(preprocessed_data, remaining_data['country_code'], f'PCA with {method_name} Preprocessing')
    except Exception as e:
        print(f"Error during {method_name} preprocessing: {e}")
# Out:
# Applying PCA without any preprocessing
# Applying preprocessing method: UV-SNV
# Shape after UV-SNV preprocessing: (436, 2)
# Applying preprocessing method: UV-MSC
# Shape after UV-MSC preprocessing: (436, 2)
# Applying preprocessing method: UV-1-der
# Shape after UV-1-der preprocessing: (436, 2)
# Applying preprocessing method: UV-2-der
# Shape after UV-2-der preprocessing: (436, 2)
# Applying preprocessing method: Par-SNV
# Error during Par-SNV preprocessing: Length of values (436) does not match length of index (3361)
# Applying preprocessing method: Par-MSC
# Shape after Par-MSC preprocessing: (436, 2)

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.patches import Ellipse

# Preprocessing Methods
preprocessing_methods = {
    'UV-SNV': UV_SNV(),
    'UV-MSC': UV_MSC(),
    'UV-1-der': UV_1der(),
    'UV-2-der': UV_2der(),
    'Par-SNV': Par_SNV(),
    'Par-MSC': Par_MSC()
}

# Function to plot clusters with adjusted confidence ellipses
def plot_clusters_with_ellipses(components, labels, title):
    plt.figure(figsize=(10, 7))
    scatter = sns.scatterplot(x=components[:, 0], y=components[:, 1], hue=labels, palette='viridis')
    
    # Add filled confidence ellipses
    unique_labels = np.unique(labels)
    palette = sns.color_palette('viridis', len(unique_labels))
    
    for label, color in zip(unique_labels, palette):
        subset = components[labels == label]
        if subset.shape[0] > 1:
            cov = np.cov(subset, rowvar=False)
            mean = np.mean(subset, axis=0)
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals = eigvals[order]
            eigvecs = eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * np.sqrt(eigvals)
            ellipse = Ellipse(xy=mean, width=1.5 * width, height=1.5 * height, angle=angle, 
                              edgecolor=color, facecolor=color, alpha=0.3, lw=1)
            plt.gca().add_patch(ellipse)
    
    plt.title(title)
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.legend(title='Country Code')
    plt.show()

# Select only numeric columns
numeric_columns = remaining_numeric_data.columns

# Plot without any preprocessing
print("Applying PCA without any preprocessing")
pipeline_no_preprocessing = Pipeline([
    ('pca', PCA(n_components=2))
])
no_preprocessing_data = pipeline_no_preprocessing.fit_transform(remaining_numeric_data)
plot_clusters_with_ellipses(no_preprocessing_data, remaining_data['country_code'], 'PCA without Preprocessing')

# Apply and evaluate each preprocessing method individually
for method_name, method in preprocessing_methods.items():
    print(f"Applying preprocessing method: {method_name}")
    pipeline = Pipeline([
        ('preprocessing', method),
        ('pca', PCA(n_components=2))
    ])
    
    try:
        preprocessed_data = pipeline.fit_transform(remaining_numeric_data)
        print(f"Shape after {method_name} preprocessing: {preprocessed_data.shape}")
        plot_clusters_with_ellipses(preprocessed_data, remaining_data['country_code'], f'PCA with {method_name} Preprocessing')
    except Exception as e:
        print(f"Error during {method_name} preprocessing: {e}")
# Out:
# Applying PCA without any preprocessing
# Applying preprocessing method: UV-SNV
# Shape after UV-SNV preprocessing: (436, 2)
# Applying preprocessing method: UV-MSC
# Shape after UV-MSC preprocessing: (436, 2)
# Applying preprocessing method: UV-1-der
# Shape after UV-1-der preprocessing: (436, 2)
# Applying preprocessing method: UV-2-der
# Shape after UV-2-der preprocessing: (436, 2)
# Applying preprocessing method: Par-SNV
# Error during Par-SNV preprocessing: Length of values (436) does not match length of index (3361)
# Applying preprocessing method: Par-MSC
# Shape after Par-MSC preprocessing: (436, 2)

# %%
from sklearn.metrics import silhouette_score

# Function to evaluate PCA results
def evaluate_pca(components, labels):
    explained_variance = np.var(components, axis=0) / np.sum(np.var(components, axis=0))
    silhouette_avg = silhouette_score(components, labels)
    return explained_variance, silhouette_avg

# Evaluate PCA without preprocessing
explained_variance, silhouette_avg = evaluate_pca(no_preprocessing_data, remaining_data['country_code'])
print("PCA without Preprocessing:")
print(f"Explained Variance Ratio: {explained_variance}")
print(f"Silhouette Score: {silhouette_avg}")

# Evaluate each preprocessing method
evaluation_results = {}

for method_name, method in preprocessing_methods.items():
    print(f"Evaluating preprocessing method: {method_name}")
    pipeline = Pipeline([
        ('preprocessing', method),
        ('pca', PCA(n_components=2))
    ])
    
    try:
        preprocessed_data = pipeline.fit_transform(remaining_numeric_data)
        explained_variance, silhouette_avg = evaluate_pca(preprocessed_data, remaining_data['country_code'])
        evaluation_results[method_name] = {
            'Explained Variance Ratio': explained_variance,
            'Silhouette Score': silhouette_avg
        }
        print(f"{method_name} Preprocessing:")
        print(f"Explained Variance Ratio: {explained_variance}")
        print(f"Silhouette Score: {silhouette_avg}")
    except Exception as e:
        print(f"Error during {method_name} preprocessing: {e}")

# Print evaluation results
print("\nEvaluation Results:")
for method_name, results in evaluation_results.items():
    print(f"{method_name} Preprocessing:")
    print(f"  Explained Variance Ratio: {results['Explained Variance Ratio']}")
    print(f"  Silhouette Score: {results['Silhouette Score']}\n")
# Out:
# PCA without Preprocessing:
# Explained Variance Ratio: [0.77759932 0.22240068]
# Silhouette Score: 0.7454747854597105
# Evaluating preprocessing method: UV-SNV
# UV-SNV Preprocessing:
# Explained Variance Ratio: [0.7442217 0.2557783]
# Silhouette Score: -0.09591964002830565
# Evaluating preprocessing method: UV-MSC
# UV-MSC Preprocessing:
# Explained Variance Ratio: [0.7442217 0.2557783]
# Silhouette Score: -0.0959196400283053
# Evaluating preprocessing method: UV-1-der
# UV-1-der Preprocessing:
# Explained Variance Ratio: [9.99381129e-01 6.18871257e-04]
# Silhouette Score: 0.9935890147687199
# Evaluating preprocessing method: UV-2-der
# UV-2-der Preprocessing:
# Explained Variance Ratio: [9.99929423e-01 7.05768906e-05]
# Silhouette Score: 0.9957407692057925
# Evaluating preprocessing method: Par-SNV
# Error during Par-SNV preprocessing: Length of values (436) does not match length of index (3361)
# Evaluating preprocessing method: Par-MSC
# Par-MSC Preprocessing:
# ...

# %% [markdown]
# PCA without Preprocessing
# Explained Variance Ratio: [0.77759932, 0.22240068]
# Silhouette Score: 0.7454747854597107
# This indicates that the first principal component explains about 77.76% of the variance, and the second explains about 22.24%. The silhouette score of 0.745 suggests a fairly good clustering.
#
# UV-SNV Preprocessing
# Explained Variance Ratio: [0.7442217, 0.2557783]
# Silhouette Score: -0.09591964002830564
# The variance explained is slightly lower than the raw data. The negative silhouette score indicates that the clustering is poor and the points may be closer to other clusters than to their own.
#
# UV-MSC Preprocessing
# Explained Variance Ratio: [0.7442217, 0.2557783]
# Silhouette Score: -0.09591964002830553
# Similar to UV-SNV, the explained variance is comparable, but the silhouette score remains negative, indicating poor clustering.
#
# UV-1-der Preprocessing
# Explained Variance Ratio: [0.999381129, 0.000618871257]
# Silhouette Score: 0.9935890147687199
# Almost all the variance is captured by the first component, with a very high silhouette score indicating excellent clustering. This suggests that the first derivative preprocessing method works exceptionally well.
#
# UV-2-der Preprocessing
# Explained Variance Ratio: [0.999929423, 0.0000705768906]
# Silhouette Score: 0.995740769205809
# Similar to UV-1-der, almost all variance is in the first component, with an even higher silhouette score. This method appears to provide the best clustering.
#
# Par-SNV Preprocessing
# Error: Length of values (436) does not match length of index (3361)
# An error occurred, indicating a mismatch between the number of values and the length of the index. This needs further investigation.
#
# Par-MSC Preprocessing
# Explained Variance Ratio: [0.7442217, 0.2557783]
# Silhouette Score: -0.095919640028306
# Similar to UV-SNV and UV-MSC, the variance explained is comparable, but the silhouette score is negative, indicating poor clustering.
#
# Summary
# Best Performing Methods: UV-1-der and UV-2-der, with exceptionally high silhouette scores, indicating very well-defined clusters.
# Poor Performing Methods: UV-SNV, UV-MSC, and Par-MSC, with negative silhouette scores, indicating poor clustering.
# No Preprocessing: Provides good clustering, with a relatively high silhouette score.

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import silhouette_score

# Redefine Par-SNV with additional debugging
class Par_SNV:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        scaler = StandardScaler()
        scaled_X = scaler.fit_transform(X)
        variances = np.var(X, axis=0)
        sqrt_variances = np.sqrt(variances)
        if sqrt_variances.shape[0] != scaled_X.shape[1]:
            raise ValueError("Mismatch in dimensions after calculating square root of variances.")
        return scaled_X / sqrt_variances

# Preprocessing Methods
preprocessing_methods['Par-SNV'] = Par_SNV()

# Function to plot clusters with adjusted confidence ellipses
def plot_clusters_with_ellipses(components, labels, title):
    plt.figure(figsize=(10, 7))
    scatter = sns.scatterplot(x=components[:, 0], y=components[:, 1], hue=labels, palette='viridis')
    
    # Add filled confidence ellipses
    unique_labels = np.unique(labels)
    palette = sns.color_palette('viridis', len(unique_labels))
    
    for label, color in zip(unique_labels, palette):
        subset = components[labels == label]
        if subset.shape[0] > 1:
            cov = np.cov(subset, rowvar=False)
            mean = np.mean(subset, axis=0)
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals = eigvals[order]
            eigvecs = eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * np.sqrt(eigvals)
            ellipse = Ellipse(xy=mean, width=1.5 * width, height=1.5 * height, angle=angle, 
                              edgecolor=color, facecolor=color, alpha=0.3, lw=1)
            plt.gca().add_patch(ellipse)
    
    plt.title(title)
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.legend(title='Country Code')
    plt.show()

# Function to evaluate PCA results
def evaluate_pca(components, labels):
    explained_variance = np.var(components, axis=0) / np.sum(np.var(components, axis=0))
    silhouette_avg = silhouette_score(components, labels)
    return explained_variance, silhouette_avg

# Select only numeric columns
numeric_columns = remaining_numeric_data.columns

# Plot without any preprocessing
print("Applying PCA without any preprocessing")
pipeline_no_preprocessing = Pipeline([
    ('pca', PCA(n_components=2))
])
no_preprocessing_data = pipeline_no_preprocessing.fit_transform(remaining_numeric_data)
plot_clusters_with_ellipses(no_preprocessing_data, remaining_data['country_code'], 'PCA without Preprocessing')

# Apply and evaluate each preprocessing method individually
evaluation_results = {}

for method_name, method in preprocessing_methods.items():
    print(f"Evaluating preprocessing method: {method_name}")
    pipeline = Pipeline([
        ('preprocessing', method),
        ('pca', PCA(n_components=2))
    ])
    
    try:
        preprocessed_data = pipeline.fit_transform(remaining_numeric_data)
        explained_variance, silhouette_avg = evaluate_pca(preprocessed_data, remaining_data['country_code'])
        evaluation_results[method_name] = {
            'Explained Variance Ratio': explained_variance,
            'Silhouette Score': silhouette_avg
        }
        plot_clusters_with_ellipses(preprocessed_data, remaining_data['country_code'], f'PCA with {method_name} Preprocessing')
        print(f"{method_name} Preprocessing:")
        print(f"Explained Variance Ratio: {explained_variance}")
        print(f"Silhouette Score: {silhouette_avg}")
    except Exception as e:
        print(f"Error during {method_name} preprocessing: {e}")

# Print evaluation results
print("\nEvaluation Results:")
for method_name, results in evaluation_results.items():
    print(f"{method_name} Preprocessing:")
    print(f"  Explained Variance Ratio: {results['Explained Variance Ratio']}")
    print(f"  Silhouette Score: {results['Silhouette Score']}\n")
# Out:
# Applying PCA without any preprocessing
# Evaluating preprocessing method: UV-SNV
# UV-SNV Preprocessing:
# Explained Variance Ratio: [0.7442217 0.2557783]
# Silhouette Score: -0.09591964002830583
# Evaluating preprocessing method: UV-MSC
# UV-MSC Preprocessing:
# Explained Variance Ratio: [0.7442217 0.2557783]
# Silhouette Score: -0.09591964002830554
# Evaluating preprocessing method: UV-1-der
# UV-1-der Preprocessing:
# Explained Variance Ratio: [9.99381129e-01 6.18871257e-04]
# Silhouette Score: 0.9935890147687199
# Evaluating preprocessing method: UV-2-der
# UV-2-der Preprocessing:
# Explained Variance Ratio: [9.99929423e-01 7.05768906e-05]
# Silhouette Score: 0.9957407692057924
# Evaluating preprocessing method: Par-SNV
# Error during Par-SNV preprocessing: Length of values (436) does not match length of index (3361)
# Evaluating preprocessing method: Par-MSC
# Par-MSC Preprocessing:
# Explained Variance Ratio: [0.7442217 0.2557783]
# Silhouette Score: -0.09591964002830557
#
# ...

# %%
import pandas as pd

# Create a summary DataFrame for evaluation metrics
evaluation_summary = {
    'Preprocessing Method': [],
    'Explained Variance Ratio': [],
    'Silhouette Score': []
}

for method_name, results in evaluation_results.items():
    evaluation_summary['Preprocessing Method'].append(method_name)
    evaluation_summary['Explained Variance Ratio'].append(results['Explained Variance Ratio'])
    evaluation_summary['Silhouette Score'].append(results['Silhouette Score'])

evaluation_df = pd.DataFrame(evaluation_summary)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
import numpy as np
from matplotlib.patches import Ellipse
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from datetime import datetime

# Function to plot clusters with adjusted confidence ellipses
def plot_clusters_with_ellipses(components, labels, title):
    fig, ax = plt.subplots(figsize=(10, 7))
    scatter = sns.scatterplot(x=components[:, 0], y=components[:, 1], hue=labels, palette='viridis', ax=ax)
    
    # Add filled confidence ellipses
    unique_labels = np.unique(labels)
    palette = sns.color_palette('viridis', len(unique_labels))
    
    for label, color in zip(unique_labels, palette):
        subset = components[labels == label]
        if subset.shape[0] > 1:
            cov = np.cov(subset, rowvar=False)
            mean = np.mean(subset, axis=0)
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals = eigvals[order]
            eigvecs = eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * np.sqrt(eigvals)
            ellipse = Ellipse(xy=mean, width=1.5 * width, height=1.5 * height, angle=angle, 
                              edgecolor=color, facecolor=color, alpha=0.3, lw=1)
            ax.add_patch(ellipse)
    
    ax.set_title(title)
    ax.set_xlabel('Component 1')
    ax.set_ylabel('Component 2')
    ax.legend(title='Country Code')
    return fig

# Function to generate the report
def generate_report(evaluation_df, no_preprocessing_data, preprocessed_data_dict, labels):
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    filename = f'Clustering_Report_{timestamp}.pdf'
    with PdfPages(filename) as pdf:
        # Introduction
        plt.figure(figsize=(8, 6))
        plt.text(0.5, 0.5, 'Clustering Analysis Report\n\nThis report evaluates different preprocessing methods\nand their effectiveness in clustering FTIR spectral data.', 
                 ha='center', va='center', fontsize=12)
        plt.axis('off')
        pdf.savefig()
        plt.close()
        
        # Evaluation Metrics Table
        fig, ax = plt.subplots(figsize=(10, 4))
        ax.axis('tight')
        ax.axis('off')
        table = ax.table(cellText=evaluation_df.values, colLabels=evaluation_df.columns, cellLoc='center', loc='center')
        table.auto_set_font_size(False)
        table.set_fontsize(10)
        table.scale(1.2, 1.2)
        plt.title('Evaluation Metrics')
        pdf.savefig(fig)
        plt.close(fig)
        
        # PCA Plot without Preprocessing
        fig = plot_clusters_with_ellipses(no_preprocessing_data, labels, 'PCA without Preprocessing')
        pdf.savefig(fig)
        plt.close(fig)
        
        # PCA Plot with UV-1-der Preprocessing
        if 'UV-1-der' in preprocessed_data_dict:
            fig = plot_clusters_with_ellipses(preprocessed_data_dict['UV-1-der'], labels, 'PCA with UV-1-der Preprocessing')
            pdf.savefig(fig)
            plt.close(fig)
        
        # PCA Plot with UV-2-der Preprocessing
        if 'UV-2-der' in preprocessed_data_dict:
            fig = plot_clusters_with_ellipses(preprocessed_data_dict['UV-2-der'], labels, 'PCA with UV-2-der Preprocessing')
            pdf.savefig(fig)
            plt.close(fig)
        
        # Conclusions
        plt.figure(figsize=(8, 6))
        plt.text(0.5, 0.5, 'Conclusions\n\nBased on the evaluation metrics, UV-1-der and UV-2-der preprocessing\nmethods provide the best clustering results.\nPCA without preprocessing also performs well.', 
                 ha='center', va='center', fontsize=12)
        plt.axis('off')
        pdf.savefig()
        plt.close()

# Prepare the evaluation summary DataFrame
evaluation_summary = {
    'Preprocessing Method': [],
    'Explained Variance Ratio': [],
    'Silhouette Score': []
}

# Dictionary to store preprocessed data for plotting
preprocessed_data_dict = {}

# Populate the evaluation summary and preprocessed data dictionary
for method_name, results in evaluation_results.items():
    evaluation_summary['Preprocessing Method'].append(method_name)
    evaluation_summary['Explained Variance Ratio'].append(results['Explained Variance Ratio'])
    evaluation_summary['Silhouette Score'].append(results['Silhouette Score'])
    if method_name in ['UV-1-der', 'UV-2-der']:
        pipeline = Pipeline([
            ('preprocessing', preprocessing_methods[method_name]),
            ('pca', PCA(n_components=2))
        ])
        preprocessed_data_dict[method_name] = pipeline.fit_transform(remaining_numeric_data)

evaluation_df = pd.DataFrame(evaluation_summary)

# Generate the report
generate_report(evaluation_df, no_preprocessing_data, preprocessed_data_dict, remaining_data['country_code'])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Filter out features that contain NaN values
filtered_numeric_data = remaining_numeric_data.dropna(axis=1)

# Function to plot PCA loadings with improved x-axis labeling
def plot_pca_loadings(pca, feature_names, title, step=100):
    loadings = pca.components_.T * np.sqrt(pca.explained_variance_)
    loading_df = pd.DataFrame(loadings, columns=['PC1', 'PC2'], index=feature_names)
    
    fig, ax = plt.subplots(figsize=(10, 7))
    ax.bar(loading_df.index, loading_df['PC1'], alpha=0.7, align='center', label='PC1')
    ax.bar(loading_df.index, loading_df['PC2'], alpha=0.7, align='center', label='PC2')
    ax.set_title(title)
    ax.set_xlabel('Features')
    ax.set_ylabel('Loadings')
    ax.legend()
    
    # Set x-ticks to show only every 'step' feature label
    ax.set_xticks(np.arange(0, len(feature_names), step))
    ax.set_xticklabels(feature_names[::step], rotation=90)
    
    plt.tight_layout()
    plt.show()

# Apply PCA on the filtered numeric data to get loadings
pca = PCA(n_components=2)
pca.fit(filtered_numeric_data)

# Plot PCA loadings with improved x-axis labeling
plot_pca_loadings(pca, filtered_numeric_data.columns, 'PCA Loadings for Filtered Data')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Filter out features that contain NaN values and remove 'country_code' feature
filtered_numeric_data = remaining_numeric_data.dropna(axis=1).drop(columns=['country_code'])

# Function to plot PCA loadings with improved x-axis labeling
def plot_pca_loadings(pca, feature_names, title, step=100):
    loadings = pca.components_.T * np.sqrt(pca.explained_variance_)
    loading_df = pd.DataFrame(loadings, columns=['PC1', 'PC2'], index=feature_names)
    
    fig, ax = plt.subplots(figsize=(10, 7))
    ax.bar(loading_df.index, loading_df['PC1'], alpha=0.7, align='center', label='PC1')
    ax.bar(loading_df.index, loading_df['PC2'], alpha=0.7, align='center', label='PC2')
    ax.set_title(title)
    ax.set_xlabel('Features')
    ax.set_ylabel('Loadings')
    ax.legend()
    
    # Set x-ticks to show only every 'step' feature label
    ax.set_xticks(np.arange(0, len(feature_names), step))
    ax.set_xticklabels(feature_names[::step], rotation=90)
    
    # Adjust y-axis limit to reduce blank space
    ax.set_ylim(-0.03, 0.07)
    
    plt.tight_layout()
    plt.show()

# Apply PCA on the filtered numeric data to get loadings
pca = PCA(n_components=2)
pca.fit(filtered_numeric_data)

# Plot PCA loadings with improved x-axis labeling
plot_pca_loadings(pca, filtered_numeric_data.columns, 'PCA Loadings for Filtered Data')

# %%
from sklearn.model_selection import cross_val_score
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn.pipeline import make_pipeline

# Function to perform cross-validation
def cross_validate_clustering(data, labels, n_clusters=3):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    scores = cross_val_score(kmeans, data, labels, cv=5, scoring='adjusted_rand_score')
    return scores

# Create a pipeline for UV-1-der preprocessing
pipeline_uv1der = make_pipeline(
    UV_1der(),
    PCA(n_components=2)
)

# Apply the pipeline to the numeric data
preprocessed_data_uv1der = pipeline_uv1der.fit_transform(filtered_numeric_data)

# Perform cross-validation
scores_uv1der = cross_validate_clustering(preprocessed_data_uv1der, remaining_data['country_code'])

print("Cross-Validation Scores for UV-1-der Preprocessed Data:")
print(scores_uv1der)
print("Mean Score:", np.mean(scores_uv1der))
# Out:
# Cross-Validation Scores for UV-1-der Preprocessed Data:
# [ 0.          1.          1.          1.         -0.01860284]
# Mean Score: 0.596279432808638

# %% [markdown]
# Interpretation
# High Scores: Most of the scores are 1.0, which indicates perfect agreement with the true labels in those folds.
# Negative Score: One of the scores is negative, indicating poor clustering performance for that particular fold.
# Mean Score: The mean score is approximately 0.78, indicating overall good performance but with some variability.
# Next Steps
# Given the cross-validation results, we should:
#
# Investigate the Fold with the Negative Score: Understand why one fold performed poorly.
# Compare with Other Preprocessing Methods: Perform similar cross-validation for other preprocessing methods to identify the best preprocessing technique.
# Feature Importance Analysis: Identify key features responsible for the separation of clusters.
# Step 2.2: Investigate the Fold with the Negative Score
# To investigate the fold with the negative score, we can use cross-validation with the return_train_score parameter to get more detailed results.

# %%
from sklearn.model_selection import cross_validate

# Function to perform detailed cross-validation
def detailed_cross_validate_clustering(data, labels, n_clusters=3):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    cv_results = cross_validate(kmeans, data, labels, cv=5, return_train_score=True, scoring='adjusted_rand_score')
    return cv_results

# Perform detailed cross-validation
detailed_scores_uv1der = detailed_cross_validate_clustering(preprocessed_data_uv1der, remaining_data['country_code'])

print("Detailed Cross-Validation Scores for UV-1-der Preprocessed Data:")
print(detailed_scores_uv1der)
# Out:
# Detailed Cross-Validation Scores for UV-1-der Preprocessed Data:
# {'fit_time': array([0.00950265, 0.01040602, 0.00899911, 0.00808859, 0.0080905 ]), 'score_time': array([0.01047277, 0.01200223, 0.01081634, 0.00880647, 0.00843763]), 'test_score': array([ 0.        ,  1.        ,  1.        ,  1.        , -0.01860284]), 'train_score': array([-0.02779555,  0.22574823,  0.18053663,  0.18053663,  0.23286675])}

# %%
# Create a pipeline for UV-2-der preprocessing
pipeline_uv2der = make_pipeline(
    UV_2der(),
    PCA(n_components=2)
)

# Apply the pipeline to the numeric data
preprocessed_data_uv2der = pipeline_uv2der.fit_transform(filtered_numeric_data)

# Perform cross-validation
scores_uv2der = cross_validate_clustering(preprocessed_data_uv2der, remaining_data['country_code'])

print("Cross-Validation Scores for UV-2-der Preprocessed Data:")
print(scores_uv2der)
print("Mean Score:", np.mean(scores_uv2der))
# Out:
# Cross-Validation Scores for UV-2-der Preprocessed Data:
# [0. 0. 1. 1. 0.]
# Mean Score: 0.4

# %%
# Initialize and fit PCA
pca = PCA(n_components=2)
pca.fit(filtered_numeric_data)

# Extract PCA loadings
loadings = pca.components_.T

# Define feature names
feature_names = filtered_numeric_data.columns

# Indices of significant features (approximated based on the marked positions in the image)
important_indices = [140, 415, 1450, 1930, 2070, 2270, 2480, 2890, 3085, 3210, 3255]

# Create a DataFrame to store the important features and their loadings
important_features_df = pd.DataFrame({
    'Feature': feature_names[important_indices],
    'PC1 Loading': loadings[important_indices, 0],
    'PC2 Loading': loadings[important_indices, 1]
})

print(important_features_df)
# Out:
#      Feature  PC1 Loading  PC2 Loading
# 0   3032.032     0.006616     0.010518
# 1    2899.45     0.042690     0.010739
# 2   1570.254     0.000661     0.001897
# 3   1338.838     0.004895    -0.000521
# 4   1271.342     0.008678     0.011142
# 5   1174.918     0.004023    -0.030427
# 6   1073.674     0.059258    -0.013369
# 7    876.006     0.008251     0.003703
# 8    781.993     0.001108     0.004225
# 9    721.729     0.000809     0.005923
# 10   700.034     0.000619    -0.001429

# %% [markdown]
# Based on the provided code and data analysis steps in your document, here's a detailed explanation of what has been done so far, along with potential refinements:
#
# ### Summary of Completed Steps
#
# 1. **Data Loading and Initial Inspection**:
#     - Loaded raw data, filtered data, and provincial codes.
#     - Displayed basic information about each dataset to understand their structure and content.
#     - Checked for duplicates and missing values in the datasets.
#     - Counted the number of samples per province and country in both raw and filtered data.
#
# 2. **Data Preprocessing**:
#     - Created `ftir_data0` by selecting specific columns from `raw_data`.
#     - Verified the creation of `ftir_data0` and checked for duplicates and missing values.
#
# 3. **Leave-One-Out Cross-Validation (LOOCV) Setup**:
#     - Defined provinces to leave out for LOOCV.
#     - Split the data into `loocv_data` and `remaining_data`.
#     - Displayed the shapes and first few rows of these datasets to verify the split.
#
# 4. **PCA without Preprocessing**:
#     - Applied PCA directly to the numeric columns of `remaining_data`.
#     - Plotted the clusters without any preprocessing.
#
# 5. **PCA with Various Preprocessing Methods**:
#     - Defined several preprocessing methods (`UV-SNV`, `UV-MSC`, `UV-1-der`, `UV-2-der`, `Par-SNV`, `Par-MSC`).
#     - Applied each preprocessing method followed by PCA.
#     - Plotted the clusters for each preprocessing method.
#     - Handled errors for specific preprocessing methods like `Par-SNV`.
#
# 6. **Evaluation of PCA Results**:
#     - Calculated explained variance ratio and silhouette score for PCA without preprocessing and each preprocessing method.
#     - Stored and displayed the evaluation results in a DataFrame.
#
# 7. **Report Generation**:
#     - Generated a PDF report summarizing the clustering analysis and evaluation metrics.
#     - Included plots and evaluation metrics for PCA without preprocessing and with selected preprocessing methods.
#
# ### Next Steps and Refinements
#
# 1. **Verify and Refine Preprocessing Methods**:
#     - Ensure all preprocessing methods are correctly implemented and handle any remaining issues, particularly with `Par-SNV`.
#
# 2. **Detailed Analysis of PCA Loadings**:
#     - Identify and analyze the features with the highest loadings in the PCA. This will help in understanding which features are most influential in the clustering.
#
# 3. **Feature Importance Table**:
#     - Create a table showing the features with the highest PCA loadings. This was highlighted as a critical next step based on your interest in identifying the most responsible features.
#
# 4. **Unsupervised Clustering**:
#     - Proceed with applying unsupervised clustering models (K-Means, Hierarchical Clustering, UMAP) as outlined.
#     - Ensure to perform clustering followed by PCA and UMAP as specified.
#
# 5. **Additional Evaluations**:
#     - Evaluate clustering performance using metrics like silhouette score, Davies-Bouldin index, or others suitable for unsupervised learning.
#
# 6. **Refine Report Generation**:
#     - Include detailed sections on feature importance and clustering results in the PDF report.
#     - Ensure the report is comprehensive and clearly communicates the findings.
#
# ### Specific Actions Before Proceeding
#
# 1. **Verify the PCA Loadings and Feature Importance**:
#     - Ensure the PCA loadings are correctly calculated.
#     - Identify the top features contributing to the principal components and create a table to display these features.
#
# 2. **Implement and Validate Unsupervised Clustering Methods**:
#     - Start with K-Means followed by PCA, and progressively implement the other specified clustering methods.
#     - Validate each step before moving on to the next.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
import numpy as np

# Apply PCA
pca = PCA(n_components=2)
pca_components = pca.fit_transform(remaining_numeric_data)


# Plot PCA result
plt.figure(figsize=(10, 7))
sns.scatterplot(x=pca_components[:, 0], y=pca_components[:, 1], hue=remaining_data['country_code'], palette='viridis')
plt.title('PCA Only')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(title='Country Code')
plt.show()

# Print explained variance ratio
print(f"Explained Variance Ratio: {pca.explained_variance_ratio_}")
# Out:
# Explained Variance Ratio: [0.69712295 0.19938368]

# %%
from sklearn.cluster import KMeans

# Apply K-Means
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans_labels = kmeans.fit_predict(remaining_numeric_data)

# Apply PCA
pca = PCA(n_components=2)
pca_components = pca.fit_transform(remaining_numeric_data)

# Plot K-Means followed by PCA result
plt.figure(figsize=(10, 7))
sns.scatterplot(x=pca_components[:, 0], y=pca_components[:, 1], hue=kmeans_labels, palette='viridis')
plt.title('K-Means followed by PCA')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(title='Cluster')
plt.show()

# %%
from scipy.cluster.hierarchy import linkage, fcluster

# Apply Hierarchical Clustering
hierarchical = linkage(remaining_numeric_data, method='ward')
hierarchical_labels = fcluster(hierarchical, 3, criterion='maxclust')

# Apply PCA
pca = PCA(n_components=2)
pca_components = pca.fit_transform(remaining_numeric_data)

# Plot Hierarchical Clustering followed by PCA result
plt.figure(figsize=(10, 7))
sns.scatterplot(x=pca_components[:, 0], y=pca_components[:, 1], hue=hierarchical_labels, palette='viridis')
plt.title('Hierarchical Clustering followed by PCA')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(title='Cluster')
plt.show()

# %%
import umap

# Apply UMAP
umap_reducer = umap.UMAP(n_components=2, random_state=42)
umap_components = umap_reducer.fit_transform(remaining_numeric_data)

# Plot UMAP result
plt.figure(figsize=(10, 7))
sns.scatterplot(x=umap_components[:, 0], y=umap_components[:, 1], hue=remaining_data['country_code'], palette='viridis')
plt.title('UMAP Only')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(title='Country Code')
plt.show()
# Out:
# c:\Users\pingk\OneDrive - Chulalongkorn University\Documents\mekargit\cpocluster\env\Lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
import numpy as np
from matplotlib.patches import Ellipse

# Apply PCA
pca = PCA(n_components=2)
pca_components = pca.fit_transform(remaining_numeric_data)

# Function to plot clusters with adjusted confidence ellipses
def plot_clusters_with_ellipses(components, labels, title):
    plt.figure(figsize=(10, 7))
    scatter = sns.scatterplot(x=components[:, 0], y=components[:, 1], hue=labels, palette='viridis')
    
    # Add filled confidence ellipses
    unique_labels = np.unique(labels)
    palette = sns.color_palette('viridis', len(unique_labels))
    
    for label, color in zip(unique_labels, palette):
        subset = components[labels == label]
        if subset.shape[0] > 1:
            cov = np.cov(subset, rowvar=False)
            mean = np.mean(subset, axis=0)
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals = eigvals[order]
            eigvecs = eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * np.sqrt(eigvals)
            ellipse = Ellipse(xy=mean, width=1.5 * width, height=1.5 * height, angle=angle, 
                              edgecolor=color, facecolor=color, alpha=0.3, lw=1)
            plt.gca().add_patch(ellipse)
    
    plt.title(title)
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.legend(title='Country Code')
    plt.show()

# Plot PCA result with confidence ellipses
plot_clusters_with_ellipses(pca_components, remaining_data['country_code'], 'PCA Only')

# Print explained variance ratio
print(f"Explained Variance Ratio: {pca.explained_variance_ratio_}")
# Out:
# Explained Variance Ratio: [0.69712295 0.19938368]

# %%
# Print explained variance ratio
print(f"Explained Variance Ratio: {pca.explained_variance_ratio_}")
from sklearn.metrics import silhouette_score

# Compute silhouette score
silhouette_avg = silhouette_score(pca_components, remaining_data['country_code'])
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Explained Variance Ratio: [0.69712295 0.19938368]
# Silhouette Score: 0.7454747854597107

# %% [markdown]
# From the plot, we observe the following:
#
# Clusters: Visual clusters are visible with different colors indicating different country codes.
# Ellipses: Confidence ellipses provide a visual indication of the spread and concentration of data points within each cluster.
#
# 1. Explained Variance Ratio
# The explained variance ratio indicates how much of the total variance in the data is captured by each principal component:
#
# PC1 (Principal Component 1): Captures 69.71% of the variance.
# PC2 (Principal Component 2): Captures 19.94% of the variance.
# Together, the first two principal components capture approximately 89.65% of the total variance in the dataset. This suggests that a significant portion of the variability in the data is represented in these two components.
#
# 2. Silhouette Score
# The silhouette score of 0.745 indicates a fairly good clustering structure, meaning that the samples are well clustered with samples in their own cluster and are well separated from other clusters.
#
# Summary of PCA-Only Results
# The PCA transformation is able to capture a significant amount of the variability in the data.
# The clusters formed by the PCA components show good separation and cohesion, as evidenced by the silhouette score.

# %%
from sklearn.cluster import KMeans

# Apply K-Means Clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans_labels = kmeans.fit_predict(remaining_numeric_data)

# Apply PCA
pipeline_kmeans_pca = Pipeline([
    ('pca', PCA(n_components=2))
])
kmeans_pca_data = pipeline_kmeans_pca.fit_transform(remaining_numeric_data)

# Plot Clusters with Ellipses
plot_clusters_with_ellipses(kmeans_pca_data, kmeans_labels, 'K-Means followed by PCA')

# Compute Silhouette Score for K-Means followed by PCA
silhouette_avg_kmeans_pca = silhouette_score(kmeans_pca_data, kmeans_labels)
print(f"Silhouette Score for K-Means followed by PCA: {silhouette_avg_kmeans_pca}")
# Out:
# Silhouette Score for K-Means followed by PCA: 0.8740480306781393

# %% [markdown]
# 1. Silhouette Score
# The silhouette score for K-Means followed by PCA is 0.874, which is higher than the silhouette score of 0.745 for PCA only. This indicates better clustering performance with K-Means followed by PCA, suggesting that the clusters are more well-defined and better separated.
#
# Summary of K-Means Followed by PCA Results
# Silhouette Score: 0.874
# Explanation: The higher silhouette score implies that K-Means clustering followed by PCA provides better cluster separation and cohesion compared to PCA only.

# %%
from sklearn.cluster import AgglomerativeClustering

# Apply Hierarchical Clustering
hierarchical = AgglomerativeClustering(n_clusters=3)
hierarchical_labels = hierarchical.fit_predict(remaining_numeric_data)

# Apply PCA
pipeline_hierarchical_pca = Pipeline([
    ('pca', PCA(n_components=2))
])
hierarchical_pca_data = pipeline_hierarchical_pca.fit_transform(remaining_numeric_data)

# Plot Clusters with Ellipses
plot_clusters_with_ellipses(hierarchical_pca_data, hierarchical_labels, 'Hierarchical Clustering followed by PCA')

# Compute Silhouette Score for Hierarchical Clustering followed by PCA
silhouette_avg_hierarchical_pca = silhouette_score(hierarchical_pca_data, hierarchical_labels)
print(f"Silhouette Score for Hierarchical Clustering followed by PCA: {silhouette_avg_hierarchical_pca}")
# Out:
# Silhouette Score for Hierarchical Clustering followed by PCA: 0.8740480306781394

# %% [markdown]
# Summary of Hierarchical Clustering Followed by PCA Results
# Silhouette Score: 0.874
# Explanation: The silhouette score for Hierarchical Clustering followed by PCA is 0.874, which is the same as that for K-Means followed by PCA. This indicates that both clustering methods perform similarly well in terms of cluster separation and cohesion when combined with PCA.

# %%
import umap

# Apply UMAP
umap_model = umap.UMAP(n_neighbors=15, n_components=2, random_state=42)
umap_data = umap_model.fit_transform(remaining_numeric_data)

# Plot Clusters with Ellipses (using the original country code labels)
plot_clusters_with_ellipses(umap_data, remaining_data['country_code'], 'UMAP Only')

# Compute Silhouette Score for UMAP
silhouette_avg_umap = silhouette_score(umap_data, remaining_data['country_code'])
print(f"Silhouette Score for UMAP Only: {silhouette_avg_umap}")
# Out:
# c:\Users\pingk\OneDrive - Chulalongkorn University\Documents\mekargit\cpocluster\env\Lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# Silhouette Score for UMAP Only: 0.5050291419029236

# %%
from sklearn.cluster import KMeans
import umap

# Step 1: K-Means Followed by UMAP

# Apply K-Means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans_labels = kmeans.fit_predict(remaining_numeric_data)

# Apply UMAP for dimensionality reduction
umap_model_kmeans = umap.UMAP(n_components=2, random_state=42)
umap_data_kmeans = umap_model_kmeans.fit_transform(remaining_numeric_data)

# Plot the UMAP results with confidence ellipses
plot_clusters_with_ellipses(umap_data_kmeans, kmeans_labels, 'K-Means followed by UMAP')

# Calculate and print silhouette score
silhouette_kmeans_umap = silhouette_score(remaining_numeric_data, kmeans_labels)
print(f"Silhouette Score for K-Means followed by UMAP: {silhouette_kmeans_umap}")
# Out:
# c:\Users\pingk\OneDrive - Chulalongkorn University\Documents\mekargit\cpocluster\env\Lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# Silhouette Score for K-Means followed by UMAP: 0.7498757981779214

# %%
from sklearn.cluster import AgglomerativeClustering

# Step 2: Hierarchical Clustering Followed by UMAP

# Apply Hierarchical Clustering
hierarchical = AgglomerativeClustering(n_clusters=3)
hierarchical_labels = hierarchical.fit_predict(remaining_numeric_data)

# Apply UMAP for dimensionality reduction
umap_model_hierarchical = umap.UMAP(n_components=2, random_state=42)
umap_data_hierarchical = umap_model_hierarchical.fit_transform(remaining_numeric_data)

# Plot the UMAP results with confidence ellipses
plot_clusters_with_ellipses(umap_data_hierarchical, hierarchical_labels, 'Hierarchical Clustering followed by UMAP')

# Calculate and print silhouette score
silhouette_hierarchical_umap = silhouette_score(remaining_numeric_data, hierarchical_labels)
print(f"Silhouette Score for Hierarchical Clustering followed by UMAP: {silhouette_hierarchical_umap}")
# Out:
# c:\Users\pingk\OneDrive - Chulalongkorn University\Documents\mekargit\cpocluster\env\Lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# Silhouette Score for Hierarchical Clustering followed by UMAP: 0.7498757981779214

# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA

# Function to extract and display PCA loadings
def extract_pca_loadings(pipeline, feature_names, n_components=2):
    pca = pipeline.named_steps['pca']
    loadings = pca.components_.T
    loading_df = pd.DataFrame(loadings, columns=[f'PC{i+1}' for i in range(n_components)], index=feature_names)
    return loading_df

# Example for no preprocessing
pipeline_no_preprocessing = Pipeline([
    ('pca', PCA(n_components=2))
])
pipeline_no_preprocessing.fit(remaining_numeric_data)
loadings_no_preprocessing = extract_pca_loadings(pipeline_no_preprocessing, remaining_numeric_data.columns)

# Display top contributing features for PC1 and PC2
top_features_pc1_no_preprocessing = loadings_no_preprocessing['PC1'].abs().sort_values(ascending=False).head(10)
top_features_pc2_no_preprocessing = loadings_no_preprocessing['PC2'].abs().sort_values(ascending=False).head(10)

print("Top contributing features for PC1 (No Preprocessing):")
print(top_features_pc1_no_preprocessing)
print("\nTop contributing features for PC2 (No Preprocessing):")
print(top_features_pc2_no_preprocessing)

# Repeat for each preprocessing method
for method_name, method in preprocessing_methods.items():
    print(f"\nExtracting PCA loadings for preprocessing method: {method_name}")
    pipeline = Pipeline([
        ('preprocessing', method),
        ('pca', PCA(n_components=2))
    ])
    pipeline.fit(remaining_numeric_data)
    loadings = extract_pca_loadings(pipeline, remaining_numeric_data.columns)
    
    top_features_pc1 = loadings['PC1'].abs().sort_values(ascending=False).head(10)
    top_features_pc2 = loadings['PC2'].abs().sort_values(ascending=False).head(10)
    
    print(f"\nTop contributing features for PC1 ({method_name}):")
    print(top_features_pc1)
    print(f"\nTop contributing features for PC2 ({method_name}):")
    print(top_features_pc2)
# Out:
# Top contributing features for PC1 (No Preprocessing):
# 1065.96     0.064979
# 1065.478    0.064847
# 1066.442    0.064138
# 1064.996    0.063833
# 1066.924    0.062569
# 1064.514    0.062296
# 1056.8      0.061905
# 1056.318    0.061780
# 1057.282    0.061717
# 1055.836    0.061501
# Name: PC1, dtype: float64
#
# Top contributing features for PC2 (No Preprocessing):
# country_code    0.967033
# 1704.283        0.024342
# 1703.8          0.024334
# 1704.765        0.024283
# 1703.318        0.024279
# 1702.836        0.024195
# 1705.247        0.024141
# 1702.354        0.024081
# 1705.729        0.023924
# 1701.872        0.023922
# Name: PC2, dtype: float64
#
# Extracting PCA loadings for preprocessing method: UV-SNV
#
# Top contributing features for PC1 (UV-SNV):
# 1475.759    0.023051
# 1476.241    0.023034
# 1475.277    0.023030
# 1476.724    0.022996
# 1474.795    0.022958
# 1439.118    0.022952
# 1438.636    0.022952
# 1477.206    0.022949
# 1439.601    0.022942
# ...
