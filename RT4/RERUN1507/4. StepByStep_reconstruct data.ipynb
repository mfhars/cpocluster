# %%
import pandas as pd

# Load the data files
raw_data_path = '/mnt/data/data_rt4_countrybased_raw_nodrop.csv'
filtered_data_path = '/mnt/data/data_rt4_countrybased_raw_remove2region.csv'
provincial_codes_path = '/mnt/data/provincial code.xlsx'

raw_data_path = r"C:\Users\pingk\Downloads\fadhli nitip\fadhli nitip\csv\data_rt4_countrybased_raw_nodrop.csv"
filtered_data_path = r"C:\Users\pingk\Downloads\fadhli nitip\fadhli nitip\csv\data_rt4_countrybased_raw_remove2region.csv"
provincial_codes_path = r"C:\Users\pingk\Downloads\fadhli nitip\provincial code.xlsx" 
                                 
raw_data = pd.read_csv(raw_data_path)
filtered_data = pd.read_csv(filtered_data_path)
provincial_codes = pd.read_excel(provincial_codes_path)

print("Data files loaded successfully.")
# Out:
# Data files loaded successfully.

# %%
# Inspect the first few rows of each dataset
print("Raw Data:")
raw_data.head()
# Out:
# Raw Data:
#   prov_char  country_code country_char               wavenumber  4000.122  \
# 0       BBX             1           ID  ID-BBX-068-2307-031_001  0.000788
# 1       BBX             1           ID  ID-BBX-068-2307-031_002  0.001095
# 2       BBX             1           ID  ID-BBX-068-2307-031_003  0.000099
# 3       BBX             1           ID  ID-BBX-068-2307-031_004  0.001685
# 4       BBX             1           ID  ID-BBX-068-2307-031_005  0.002118
#
#     3999.64  3999.158  3998.676  3998.194  3997.712  ...    653.75   653.268  \
# 0  0.000813  0.000840  0.000858  0.000862  0.000843  ...  0.011951  0.013370
# 1  0.001078  0.001086  0.001114  0.001151  0.001180  ...  0.012086  0.011914
# 2  0.000153  0.000288  0.000470  0.000658  0.000814  ...  0.010487  0.011307
# 3  0.001802  0.001903  0.001975  0.002017  0.002031  ...  0.008177  0.008240
# 4  0.002196  0.002266  0.002324  0.002369  0.002404  ...  0.009831  0.010143
#
# ...

# %%
print("\nFiltered Data:")
filtered_data.head()
# Out:
# Filtered Data:
#   prov_char  country_code country_char               wavenumber  3099.528  \
# 0       BBX             1           ID  ID-BBX-068-2307-031_001  0.002471
# 1       BBX             1           ID  ID-BBX-068-2307-031_002  0.002932
# 2       BBX             1           ID  ID-BBX-068-2307-031_003  0.001651
# 3       BBX             1           ID  ID-BBX-068-2307-031_004  0.003385
# 4       BBX             1           ID  ID-BBX-068-2307-031_005  0.002765
#
#    3099.046  3098.564  3098.082    3097.6  3097.118  ...   654.232    653.75  \
# 0  0.002400  0.002327  0.002251  0.002176  0.002106  ...  0.010798  0.011951
# 1  0.002932  0.002909  0.002861  0.002796  0.002721  ...  0.012223  0.012086
# 2  0.001675  0.001680  0.001666  0.001634  0.001589  ...  0.010014  0.010487
# 3  0.003437  0.003485  0.003524  0.003555  0.003571  ...  0.008214  0.008177
# 4  0.002775  0.002776  0.002755  0.002706  0.002632  ...  0.009767  0.009831
#
# ...

# %%
print("\nProvincial Codes:")
provincial_codes.head()
# Out:
# Provincial Codes:
#   prov__char
# 0        SNI
# 1        KBI
# 2        CPN
# 3        SKM
# 4        PKN

# %%
# Display basic information about each dataset
print("\nRaw Data Info:")
raw_data.info()
# Out:
# Raw Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Columns: 6955 entries, prov_char to 16158804.55800001
# dtypes: float64(6951), int64(1), object(3)
# memory usage: 23.7+ MB

# %%
print("\nFiltered Data Info:")
filtered_data.info()
# Out:
# Filtered Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Columns: 3364 entries, prov_char to 649.893
# dtypes: float64(3360), int64(1), object(3)
# memory usage: 11.5+ MB

# %%
print("\nProvincial Codes Info:")
provincial_codes.info()
# Out:
# Provincial Codes Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   prov__char  28 non-null     object
# dtypes: object(1)
# memory usage: 356.0+ bytes

# %%
# Create ftir_data0 with specified columns from raw_data
ftir_data0 = raw_data.iloc[:, 4:-1]

# Verify the creation of ftir_data0
print("FTIR Data 0:")
print(ftir_data0.head())
print(ftir_data0.info())
# Out:
# FTIR Data 0:
#    4000.122   3999.64  3999.158  3998.676  3998.194  3997.712   3997.23  \
# 0  0.000788  0.000813  0.000840  0.000858  0.000862  0.000843  0.000797
# 1  0.001095  0.001078  0.001086  0.001114  0.001151  0.001180  0.001182
# 2  0.000099  0.000153  0.000288  0.000470  0.000658  0.000814  0.000909
# 3  0.001685  0.001802  0.001903  0.001975  0.002017  0.002031  0.002019
# 4  0.002118  0.002196  0.002266  0.002324  0.002369  0.002404  0.002435
#
#    3996.747  3996.265  3995.783  ...   654.232    653.75   653.268   652.786  \
# 0  0.000719  0.000609  0.000476  ...  0.010798  0.011951  0.013370  0.014849
# 1  0.001144  0.001064  0.000951  ...  0.012223  0.012086  0.011914  0.011799
# 2  0.000928  0.000871  0.000755  ...  0.010014  0.010487  0.011307  0.012372
# 3  0.001983  0.001925  0.001851  ...  0.008214  0.008177  0.008240  0.008484
# 4  0.002460  0.002472  0.002461  ...  0.009767  0.009831  0.010143  0.010621
#
# ...

# %%
# Check for duplicates in raw_data, filtered_data, and ftir_data0
filtered_data_duplicates = filtered_data.duplicated().sum()
ftir_data0_duplicates = ftir_data0.duplicated().sum()

print(f"Duplicates in Filtered Data: {filtered_data_duplicates}")
print(f"Duplicates in FTIR Data 0: {ftir_data0_duplicates}")
# Out:
# Duplicates in Filtered Data: 0
# Duplicates in FTIR Data 0: 0

# %%
# Check for missing values in raw_data, filtered_data, and ftir_data0
filtered_data_missing = filtered_data.isna().sum()
ftir_data0_missing = ftir_data0.isna().sum()

print("\nMissing Values in Filtered Data:")
print(filtered_data_missing[filtered_data_missing > 0])

print("\nMissing Values in FTIR Data 0:")
print(ftir_data0_missing[ftir_data0_missing > 0])
# Out:
# Missing Values in Filtered Data:
# Series([], dtype: int64)
#
# Missing Values in FTIR Data 0:
# Series([], dtype: int64)

# %%
# Count the number of samples per province and per country in filtered_data
sample_count_per_province_filtered = filtered_data['prov_char'].value_counts()
sample_count_per_country_filtered = filtered_data['country_char'].value_counts()

# Count the number of samples per province and per country in raw_data (since ftir_data0 is derived from it)
sample_count_per_province_raw = raw_data['prov_char'].value_counts()
sample_count_per_country_raw = raw_data['country_char'].value_counts()

print("Sample Count per Province in Filtered Data:")
print(sample_count_per_province_filtered)

print("\nSample Count per Country in Filtered Data:")
print(sample_count_per_country_filtered)

print("\nSample Count per Province in Raw Data:")
print(sample_count_per_province_raw)

print("\nSample Count per Country in Raw Data:")
print(sample_count_per_country_raw)
# Out:
# Sample Count per Province in Filtered Data:
# prov_char
# SNI    75
# CPN    42
# TRG    39
# KBI    37
# NRT    24
# SNK    24
# NWT    24
# BBX    18
# KBX    18
# PKN    18
# SUX    18
# RNG    16
# STN    15
# CCO    13
# CBI    12
# RIX    11
# SGR    11
# PTN     7
# KRI     6
# KTX     5
# SSX     3
# PNA     3
# PLG     3
# SKM     3
# JHR     2
# Name: count, dtype: int64
#
# Sample Count per Country in Filtered Data:
# country_char
# TH    361
# ID     73
# MY     13
# Name: count, dtype: int64
#
# Sample Count per Province in Raw Data:
# prov_char
# SNI    75
# CPN    42
# TRG    39
# KBI    37
# NRT    24
# SNK    24
# NWT    24
# BBX    18
# KBX    18
# PKN    18
# SUX    18
# RNG    16
# STN    15
# CCO    13
# CBI    12
# RIX    11
# SGR    11
# PTN     7
# KRI     6
# KTX     5
# SSX     3
# PNA     3
# PLG     3
# SKM     3
# JHR     2
# Name: count, dtype: int64
#
# Sample Count per Country in Raw Data:
# country_char
# TH    361
# ID     73
# MY     13
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the matplotlib figure
plt.figure(figsize=(12, 6))

# Plot the distribution of samples per province in filtered_data
plt.subplot(1, 2, 1)
sns.countplot(y='prov_char', data=filtered_data, order=filtered_data['prov_char'].value_counts().index)
plt.title('Distribution of Samples per Province in Filtered Data')
plt.xlabel('Count')
plt.ylabel('Province')

# Plot the distribution of samples per country in filtered_data
plt.subplot(1, 2, 2)
sns.countplot(y='country_char', data=filtered_data, order=filtered_data['country_char'].value_counts().index)
plt.title('Distribution of Samples per Country in Filtered Data')
plt.xlabel('Count')
plt.ylabel('Country')

# Display the plots
plt.tight_layout()
plt.show()

# %%
# LOOCV Setup
def loocv_setup(data, leave_out_provinces):
    loocv_data = data[data['prov_char'].isin(leave_out_provinces)]
    remaining_data = data[~data['prov_char'].isin(leave_out_provinces)]
    return loocv_data, remaining_data

# Define the provinces to leave out for LOOCV
leave_out_provinces = ['SKM', 'PLG', 'SSX', 'JHR']

# Perform LOOCV Setup
loocv_data, remaining_data = loocv_setup(filtered_data, leave_out_provinces)

# Verify the shapes of the resulting data frames
print(f"LOOCV Data Shape: {loocv_data.shape}")
print(f"Remaining Data Shape: {remaining_data.shape}")

# Display the first few rows of LOOCV Data and Remaining Data
print("LOOCV Data:")
print(loocv_data.head())

print("\nRemaining Data:")
print(remaining_data.head())
# Out:
# LOOCV Data Shape: (11, 3364)
# Remaining Data Shape: (436, 3364)
# LOOCV Data:
#     prov_char  country_code country_char               wavenumber  3099.528  \
# 52        SSX             1           ID  ID-SSX-068-2307-028_001  0.002032
# 53        SSX             1           ID  ID-SSX-068-2307-028_002  0.001743
# 54        SSX             1           ID  ID-SSX-068-2307-028_003  0.002459
# 249       PLG             0           TH  TH-PLG-002-2209-022_001  0.002356
# 250       PLG             0           TH  TH-PLG-002-2209-022_002  0.003575
#
#      3099.046  3098.564  3098.082    3097.6  3097.118  ...   654.232  \
# 52   0.002053  0.002090  0.002141  0.002199  0.002253  ...  0.010885
# 53   0.001712  0.001692  0.001686  0.001695  0.001718  ...  0.013582
# 54   0.002432  0.002368  0.002282  0.002185  0.002091  ...  0.011873
# 249  0.002346  0.002360  0.002397  0.002453  0.002520  ...  0.007780
# 250  0.003574  0.003572  0.003578  0.003599  0.003633  ...  0.010931
#
# ...

# %%
import numpy as np

# Select only numeric columns from remaining_data
numeric_columns = remaining_data.select_dtypes(include=[np.number]).columns
remaining_numeric_data = remaining_data[numeric_columns].drop(columns=['country_code'])

# Display basic information about the numeric data
print("Numeric Data Info:")
print(remaining_numeric_data.info())

# Display first few rows of the numeric data
print("\nFirst Few Rows of Numeric Data:")
print(remaining_numeric_data.head())
# Out:
# Numeric Data Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 436 entries, 0 to 446
# Columns: 3360 entries, 3099.528 to 649.893
# dtypes: float64(3360)
# memory usage: 11.2 MB
# None
#
# First Few Rows of Numeric Data:
#    3099.528  3099.046  3098.564  3098.082    3097.6  3097.118  3096.636  \
# 0  0.002471  0.002400  0.002327  0.002251  0.002176  0.002106  0.002054
# 1  0.002932  0.002932  0.002909  0.002861  0.002796  0.002721  0.002646
# 2  0.001651  0.001675  0.001680  0.001666  0.001634  0.001589  0.001537
# 3  0.003385  0.003437  0.003485  0.003524  0.003555  0.003571  0.003569
# 4  0.002765  0.002775  0.002776  0.002755  0.002706  0.002632  0.002539
#
#    3096.154  3095.671  3095.189  ...   654.232    653.75   653.268   652.786  \
# 0  0.002030  0.002042  0.002089  ...  0.010798  0.011951  0.013370  0.014849
# 1  0.002579  0.002526  0.002490  ...  0.012223  0.012086  0.011914  0.011799
# 2  0.001487  0.001451  0.001440  ...  0.010014  0.010487  0.011307  0.012372
# ...

# %% [markdown]
# LET'S PLAY FOOTBALL

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler, RobustScaler

# Preprocessing Methods
class UV_SNV:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        scaler = RobustScaler()
        return scaler.fit_transform(X)

class UV_MSC:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        mean_spectrum = np.mean(X, axis=0)
        return (X - mean_spectrum) / np.std(X, axis=0)

class UV_1der:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return np.gradient(X, axis=1)

class UV_2der:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return np.gradient(np.gradient(X, axis=1), axis=1)

class Par_SNV:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        scaler = StandardScaler()
        scaled_X = scaler.fit_transform(X)
        variances = np.var(X, axis=0)
        sqrt_variances = np.sqrt(variances)
        if sqrt_variances.shape[0] != scaled_X.shape[1]:
            sqrt_variances = sqrt_variances[:scaled_X.shape[1]]  # Adjust the shape
        return scaled_X / sqrt_variances

class Par_MSC:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        mean_spectrum = np.mean(X, axis=0)
        variances = np.var(X, axis=0)
        sqrt_variances = np.sqrt(variances)
        if sqrt_variances.shape[0] != X.shape[1]:
            sqrt_variances = sqrt_variances[:X.shape[1]]  # Adjust the shape
        return (X - mean_spectrum) / sqrt_variances

preprocessing_methods = {
    'UV-SNV': UV_SNV(),
    'UV-MSC': UV_MSC(),
    'UV-1-der': UV_1der(),
    'UV-2-der': UV_2der(),
    'Par-SNV': Par_SNV(),
    'Par-MSC': Par_MSC()
}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.metrics import silhouette_score
from matplotlib.patches import Ellipse

# Function to plot clusters with ellipses and boundaries
def plot_clusters_with_ellipses_and_boundaries(components, labels, title, country_mapping):
    plt.figure(figsize=(10, 7))
    scatter = sns.scatterplot(x=components[:, 0], y=components[:, 1], hue=labels, palette='viridis', legend='full')
    
    # Add filled confidence ellipses
    unique_labels = np.unique(labels)
    palette = sns.color_palette('viridis', len(unique_labels))
    
    for label, color in zip(unique_labels, palette):
        subset = components[labels == label]
        if subset.shape[0] > 1:
            cov = np.cov(subset, rowvar=False)
            mean = np.mean(subset, axis=0)
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals = eigvals[order]
            eigvecs = eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * np.sqrt(eigvals)
            ellipse = Ellipse(xy=mean, width=1.5 * width, height=1.5 * height, angle=angle, 
                              edgecolor=color, facecolor=color, alpha=0.3, lw=1)
            plt.gca().add_patch(ellipse)
    
    plt.title(title)
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    
    # Add custom legend with country names
    handles, _ = scatter.get_legend_handles_labels()
    plt.legend(handles=handles, labels=[country_mapping[label] for label in unique_labels], title='Country Code')
    plt.show()

# Country mapping
country_mapping = {0: 'Thailand', 1: 'Indonesia', 2: 'Malaysia'}

# PCA without any preprocessing
pipeline_no_preprocessing = Pipeline([
    ('pca', PCA(n_components=2))
])
components_no_preprocessing = pipeline_no_preprocessing.fit_transform(remaining_numeric_data)
plot_clusters_with_ellipses_and_boundaries(components_no_preprocessing, remaining_data['country_code'], 'PCA Only', country_mapping)

silhouette_score_no_preprocessing = silhouette_score(components_no_preprocessing, remaining_data['country_code'])
print(f'Silhouette Score for PCA Only: {silhouette_score_no_preprocessing}')
# Out:
# Silhouette Score for PCA Only: -0.30298515357220546

# %%
from sklearn.cluster import KMeans

# K-Means followed by PCA
kmeans = KMeans(n_clusters=3, random_state=42)
labels_kmeans = kmeans.fit_predict(remaining_numeric_data)

pipeline_kmeans_pca = Pipeline([
    ('pca', PCA(n_components=2))
])
components_kmeans_pca = pipeline_kmeans_pca.fit_transform(remaining_numeric_data)
plot_clusters_with_ellipses_and_boundaries(components_kmeans_pca, labels_kmeans, 'K-Means followed by PCA', country_mapping)

silhouette_score_kmeans_pca = silhouette_score(components_kmeans_pca, labels_kmeans)
print(f'Silhouette Score for K-Means followed by PCA: {silhouette_score_kmeans_pca}')
# Out:
# Silhouette Score for K-Means followed by PCA: 0.8945563371209916

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score
import umap
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# Ensure 'remaining_numeric_data' is updated without 'country_code' and 'country_char'
# Assuming 'remaining_numeric_data' contains only numeric features for clustering

# Mapping of country codes to names
#country_mapping = {0: 'Thailand', 1: 'Indonesia', 2: 'Malaysia'}

# Function to plot clusters with ellipses and boundaries
def plot_clusters_with_ellipses_and_boundaries(components, labels, title) #, country_mapping):
    plt.figure(figsize=(10, 7))
    scatter = sns.scatterplot(x=components[:, 0], y=components[:, 1], hue=labels, palette='viridis', legend='full')
    
    unique_labels = np.unique(labels)
    palette = sns.color_palette('viridis', len(unique_labels))
    
    for label, color in zip(unique_labels, palette):
        subset = components[labels == label]
        if subset.shape[0] > 1:
            cov = np.cov(subset, rowvar=False)
            mean = np.mean(subset, axis=0)
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals = eigvals[order]
            eigvecs = eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * np.sqrt(eigvals)
            ellipse = Ellipse(xy=mean, width=1.5 * width, height=1.5 * height, angle=angle, 
                              edgecolor=color, facecolor=color, alpha=0.3, lw=1)
            plt.gca().add_patch(ellipse)
    
    plt.title(title)
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.show()

# Perform PCA
pca = PCA(n_components=2)
pca_components = pca.fit_transform(remaining_numeric_data)

# Perform K-Means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans_labels = kmeans.fit_predict(remaining_numeric_data)

# Perform Hierarchical Clustering
hierarchical = AgglomerativeClustering(n_clusters=3)
hierarchical_labels = hierarchical.fit_predict(remaining_numeric_data)

# Perform UMAP
umap_reducer = umap.UMAP(n_components=2, random_state=42)
umap_components = umap_reducer.fit_transform(remaining_numeric_data)

# Perform K-Means followed by UMAP
kmeans_umap_labels = kmeans.fit_predict(umap_components)

# Perform Hierarchical Clustering followed by UMAP
hierarchical_umap_labels = hierarchical.fit_predict(umap_components)

# Plot results
plot_clusters_with_ellipses_and_boundaries(pca_components, kmeans_labels, 'K-Means followed by PCA', country_mapping)
plot_clusters_with_ellipses_and_boundaries(pca_components, hierarchical_labels, 'Hierarchical Clustering followed by PCA', country_mapping)
plot_clusters_with_ellipses_and_boundaries(umap_components, kmeans_umap_labels, 'K-Means followed by UMAP', country_mapping)
plot_clusters_with_ellipses_and_boundaries(umap_components, hierarchical_umap_labels, 'Hierarchical Clustering followed by UMAP', country_mapping)
# Out:
# c:\Users\pingk\OneDrive - Chulalongkorn University\Documents\mekargit\cpocluster\env\Lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
# Combine clustering results with original country labels
results = remaining_data[['country_code', 'country_char']].copy()
results['PCA1'] = pca_components[:, 0]
results['PCA2'] = pca_components[:, 1]
results['KMeans_Labels'] = kmeans_labels
results['Hierarchical_Labels'] = hierarchical_labels
results['UMAP1'] = umap_components[:, 0]
results['UMAP2'] = umap_components[:, 1]
results['KMeans_UMAP_Labels'] = kmeans_umap_labels
results['Hierarchical_UMAP_Labels'] = hierarchical_umap_labels

# Map country codes to country names
results['country_name'] = results['country_code'].map(country_mapping)

# Display the first few rows of the results
print(results.head())
# Out:
#    country_code country_char      PCA1      PCA2  KMeans_Labels  \
# 0             1           ID -0.283624  0.005037              0
# 1             1           ID -0.267375  0.009527              0
# 2             1           ID -0.280414  0.003089              0
# 3             1           ID -0.258991  0.016136              0
# 4             1           ID -0.267802  0.010981              0
#
#    Hierarchical_Labels      UMAP1     UMAP2  KMeans_UMAP_Labels  \
# 0                    2  16.647476  3.755965                   0
# 1                    2  16.626091  3.814609                   0
# 2                    2  16.610714  3.828829                   0
# 3                    2  16.727711  3.684376                   0
# 4                    2  16.689533  3.798299                   0
#
#    Hierarchical_UMAP_Labels country_name
# 0                         0    Indonesia
# 1                         0    Indonesia
# 2                         0    Indonesia
# ...

# %%
# Evaluate K-Means clustering with PCA
kmeans_pca_table = results.groupby(['KMeans_Labels', 'country_name']).size().unstack(fill_value=0)
print('K-Means followed by PCA:')
print(kmeans_pca_table)

# Evaluate Hierarchical Clustering with PCA
hierarchical_pca_table = results.groupby(['Hierarchical_Labels', 'country_name']).size().unstack(fill_value=0)
print('Hierarchical Clustering followed by PCA:')
print(hierarchical_pca_table)

# Evaluate K-Means with UMAP
kmeans_umap_table = results.groupby(['KMeans_UMAP_Labels', 'country_name']).size().unstack(fill_value=0)
print('K-Means followed by UMAP:')
print(kmeans_umap_table)

# Evaluate Hierarchical Clustering with UMAP
hierarchical_umap_table = results.groupby(['Hierarchical_UMAP_Labels', 'country_name']).size().unstack(fill_value=0)
print('Hierarchical Clustering followed by UMAP:')
print(hierarchical_umap_table)
# Out:
# K-Means followed by PCA:
# country_name   Indonesia  Malaysia  Thailand
# KMeans_Labels
# 0                     52        11       346
# 1                      0         0         9
# 2                     18         0         0
# Hierarchical Clustering followed by PCA:
# country_name         Indonesia  Malaysia  Thailand
# Hierarchical_Labels
# 0                           18         0         1
# 1                            0         0         9
# 2                           52        11       345
# K-Means followed by UMAP:
# country_name        Indonesia  Malaysia  Thailand
# KMeans_UMAP_Labels
# 0                          45         0       225
# 1                           7        11       121
# 2                          18         0         9
# Hierarchical Clustering followed by UMAP:
# country_name              Indonesia  Malaysia  Thailand
# Hierarchical_UMAP_Labels
# 0                                45         0       225
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering
import umap
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import silhouette_score
from matplotlib.patches import Ellipse

# Preprocessing Classes
class UV_SNV:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        scaler = RobustScaler()
        return scaler.fit_transform(X)

class UV_MSC:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        mean_spectrum = np.mean(X, axis=0)
        return (X - mean_spectrum) / np.std(X, axis=0)

class UV_1der:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return np.gradient(X, axis=1)

class UV_2der:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return np.gradient(np.gradient(X, axis=1), axis=1)

class Par_MSC:
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        mean_spectrum = np.mean(X, axis=0)
        return (X - mean_spectrum) / np.sqrt(np.var(X, axis=0))

# Function to plot clusters with ellipses and boundaries
def plot_clusters_with_ellipses_and_boundaries(components, labels, title, country_labels):
    plt.figure(figsize=(10, 7))
    scatter = sns.scatterplot(x=components[:, 0], y=components[:, 1], hue=country_labels, palette='viridis', legend='full')
    
    unique_labels = np.unique(labels)
    palette = sns.color_palette('viridis', len(unique_labels))
    
    for label, color in zip(unique_labels, palette):
        subset = components[labels == label]
        if subset.shape[0] > 1:
            cov = np.cov(subset, rowvar=False)
            mean = np.mean(subset, axis=0)
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals = eigvals[order]
            eigvecs = eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * np.sqrt(eigvals)
            ellipse = Ellipse(xy=mean, width=width, height=height, angle=angle, 
                              edgecolor=color, facecolor=color, alpha=0.3, lw=1)
            plt.gca().add_patch(ellipse)
    
    plt.title(title)
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.show()

# Preprocessing Methods
preprocessing_methods = {
    'UV-SNV': UV_SNV(),
    'UV-MSC': UV_MSC(),
    'UV-1-der': UV_1der(),
    'UV-2-der': UV_2der(),
    'Par-MSC': Par_MSC()
}

# Apply each preprocessing method and perform clustering
for method_name, method in preprocessing_methods.items():
    print(f"Applying preprocessing method: {method_name}")
    
    # Apply PCA
    pipeline_pca = Pipeline([
        ('preprocessing', method),
        ('pca', PCA(n_components=2))
    ])
    components_pca = pipeline_pca.fit_transform(remaining_numeric_data)
    
    # Apply K-Means followed by PCA
    kmeans = KMeans(n_clusters=3, random_state=42)
    kmeans_labels = kmeans.fit_predict(remaining_numeric_data)
    plot_clusters_with_ellipses_and_boundaries(components_pca, kmeans_labels, f'K-Means followed by PCA with {method_name}', remaining_data['country_code'])
    
    # Apply Hierarchical Clustering followed by PCA
    hierarchical = AgglomerativeClustering(n_clusters=3)
    hierarchical_labels = hierarchical.fit_predict(remaining_numeric_data)
    plot_clusters_with_ellipses_and_boundaries(components_pca, hierarchical_labels, f'Hierarchical Clustering followed by PCA with {method_name}', remaining_data['country_code'])
    
    # Apply UMAP
    umap_reducer = umap.UMAP(n_components=2, random_state=42)
    components_umap = umap_reducer.fit_transform(remaining_numeric_data)
    plot_clusters_with_ellipses_and_boundaries(components_umap, kmeans_labels, f'K-Means followed by UMAP with {method_name}', remaining_data['country_code'])
    plot_clusters_with_ellipses_and_boundaries(components_umap, hierarchical_labels, f'Hierarchical Clustering followed by UMAP with {method_name}', remaining_data['country_code'])
    
    # Calculate silhouette scores
    silhouette_pca = silhouette_score(components_pca, kmeans_labels)
    silhouette_hierarchical_pca = silhouette_score(components_pca, hierarchical_labels)
    silhouette_umap = silhouette_score(components_umap, kmeans_labels)
    silhouette_hierarchical_umap = silhouette_score(components_umap, hierarchical_labels)
    
    print(f'Silhouette Score for K-Means followed by PCA with {method_name}: {silhouette_pca}')
    print(f'Silhouette Score for Hierarchical Clustering followed by PCA with {method_name}: {silhouette_hierarchical_pca}')
    print(f'Silhouette Score for K-Means followed by UMAP with {method_name}: {silhouette_umap}')
    print(f'Silhouette Score for Hierarchical Clustering followed by UMAP with {method_name}: {silhouette_hierarchical_umap}')

    # Combine clustering results with original country labels
    results = remaining_data[['country_code', 'country_char']].copy()
    results['PCA1'] = components_pca[:, 0]
    results['PCA2'] = components_pca[:, 1]
    results['KMeans_Labels'] = kmeans_labels
    results['Hierarchical_Labels'] = hierarchical_labels
    results['UMAP1'] = components_umap[:, 0]
    results['UMAP2'] = components_umap[:, 1]

    # Display the first few rows of the results
    print(results.head())

    # Evaluate K-Means clustering with PCA
    kmeans_pca_table = results.groupby(['KMeans_Labels', 'country_char']).size().unstack(fill_value=0)
    print(f'K-Means followed by PCA with {method_name}:')
    print(kmeans_pca_table)

    # Evaluate Hierarchical Clustering with PCA
    hierarchical_pca_table = results.groupby(['Hierarchical_Labels', 'country_char']).size().unstack(fill_value=0)
    print(f'Hierarchical Clustering followed by PCA with {method_name}:')
    print(hierarchical_pca_table)

    # Evaluate K-Means with UMAP
    kmeans_umap_table = results.groupby(['KMeans_Labels', 'country_char']).size().unstack(fill_value=0)
    print(f'K-Means followed by UMAP with {method_name}:')
    print(kmeans_umap_table)

    # Evaluate Hierarchical Clustering with UMAP
    hierarchical_umap_table = results.groupby(['Hierarchical_Labels', 'country_char']).size().unstack(fill_value=0)
    print(f'Hierarchical Clustering followed by UMAP with {method_name}:')
    print(hierarchical_umap_table)
# Out:
# Applying preprocessing method: UV-SNV
# c:\Users\pingk\OneDrive - Chulalongkorn University\Documents\mekargit\cpocluster\env\Lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# Silhouette Score for K-Means followed by PCA with UV-SNV: 0.8948951786925411
# Silhouette Score for Hierarchical Clustering followed by PCA with UV-SNV: 0.8919857172753384
# Silhouette Score for K-Means followed by UMAP with UV-SNV: 0.6326334476470947
# Silhouette Score for Hierarchical Clustering followed by UMAP with UV-SNV: 0.6232216954231262
#    country_code country_char       PCA1       PCA2  KMeans_Labels  \
# 0             1           ID -75.261701 -26.616937              0
# 1             1           ID -72.547736 -22.605266              0
# 2             1           ID -76.260923 -28.081234              0
# ...
